# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [18, 10] 

from tqdm import tqdm
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_timedata = pd.read_csv(r'/content/drive/MyDrive/Data Science Projects/OSA Project PhD/Datasets/BP Time series alignment /Grenoble_raw.csv')
UNID = df_timedata['UNID'].unique()

# %%
# !pip install FPDF
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for FPDF: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40725 sha256=cf85180b2a10d87f1f7c77884bdce22cd279b6f175100e920254958245f6bf0b
#   Stored in directory: /root/.cache/pip/wheels/d7/ca/c8/86467e7957bbbcbdf4cf4870fc7dc95e9a16404b2e3c3a98c3
# Successfully built FPDF
# ...

# %%
from fpdf import FPDF 
from os.path import exists

# %%
pdf = FPDF()
epw = pdf.w - 2*pdf.l_margin
pdf.set_font('Arial', '', 7.0)
pbar = tqdm(total = (len(UNID)*(len(UNID)-1))/2)
for i in range(len(UNID)):
  for j in range(i, len(UNID)):
    pbar.update(1)
    if not exists('/content/drive/MyDrive/sbp_plots_all/sbp_'+UNID[i]+"_"+UNID[j]+'.png'):
      continue    
    pdf.add_page()
    th = pdf.font_size
    pdf.cell(5)
    pdf.cell(176, 2*th, UNID[i], border=1, align='c')
    pdf.ln(2*th)
    pdf.cell(5)
    pdf.cell(176, 2*th, UNID[j], border=1, align='c')

    pdf.image('/content/drive/MyDrive/sbp_plots_all/sbp_'+UNID[i]+"_"+UNID[j]+'.png', 20,20,150)
pbar.close()
pdf.output('sbp.pdf', 'F')
# Out:
#   2%|▏         | 606/39903.0 [04:16<4:30:32,  2.42it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2053bfe47cbf> in <module>()
#      17     pdf.cell(176, 2*th, UNID[j], border=1, align='c')
#      18
# ---> 19     pdf.image('/content/drive/MyDrive/sbp_plots_all/sbp_'+UNID[i]+"_"+UNID[j]+'.png', 20,20,150)
#      20 pbar.close()
#      21 pdf.output('sbp.pdf', 'F')
#
# /usr/local/lib/python3.7/dist-packages/fpdf/fpdf.py in wrapper(self, *args, **kwargs)
#     148                 self.error("No page open, you need to call add_page() first")
#     149             else:
# --> 150                 return fn(self, *args, **kwargs)
#     151         return wrapper
#     152
#
# /usr/local/lib/python3.7/dist-packages/fpdf/fpdf.py in image(self, name, x, y, w, h, type, link)
#     969                 info=self._parsejpg(name)
# ...

# %%
# !ls "/content/drive/MyDrive/Data Science Projects/OSA Project PhD/Datasets/BP Time series alignment /sbp_plots_all/" | wc -l

# %%
# !cat '/content/drive/MyDrive/sbp_plots_all/sbp_1907f4a6-b068-428d-a88e-38ca9df121f6_1907f4a6-b068-428d-a88e-38ca9df121f6.png'
# Out:
# cat: /content/drive/MyDrive/sbp_plots_all/sbp_1907f4a6-b068-428d-a88e-38ca9df121f6_1907f4a6-b068-428d-a88e-38ca9df121f6.png: No such file or directory
